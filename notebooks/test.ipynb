# %%
from speedy_utils import *
from llm_utils import *

# %%
llm = LLM(client=8000, is_reasoning_model=True)

# %%
# !uv add transformers
# Out:
# Resolved 409 packages in 2.30s
# Prepared 3 packages in 10.22s
# Uninstalled 1 package in 5ms
# Installed 4 packages in 39ms(from file:///Users/anhvth/proje
#  + regex==2026.1.15
#  + safetensors==0.7.0
#  ~ speedy-utils==1.2.11 (from file:///Users/anhvth/projects/speedy_utils)
#  + transformers==4.57.6

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen3.5-397B-A17B-FP8')

# %%
messages = get_conversation_one_turn('you are name', 'hello /think /glm')
chat = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True, )
print(chat)
# Out:
# <|im_start|>system
# you are name<|im_end|>
# <|im_start|>user
# hello /think /glm<|im_end|>
# <|im_start|>assistant
# <think>

# %%
llm.generate(chat, max_tokens=300)
# Out:
# {'text': '\n</think>\n\nHello! It seems you are initiating a conversation. How may I assist you today?<|im_end|>',
#  'finish_reason': 'stop',
#  '_raw_response': {'request_id': '8739af3b1c1e0ffa',
#   'choices': [{'index': 0,
#     'logprobs': None,
#     'finish_reason': 'stop',
#     'token_ids': [198,
#      248069,
#      271,
#      9419,
#      0,
#      1049,
#      4816,
#      488,
#      513,
#      75728,
#      264,
#      10125,
#      13,
#      2500,
#      1189,
#      353,
#      7543,
#      488,
#      3242,
#      30,
#      248046]}],
#   'prompt_logprobs': None,
#   'kv_transfer_params': None}}
